# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import os
import pandas as pd

# %%
dataset = pd.read_csv("features.csv", skipinitialspace=True)
dataset = dataset.drop(dataset.columns[0], axis= 1)
dataset.dropna(subset=['_type'], inplace=True)
dataset.head(10)
# Out:
#                              _type  \
# 0   snscrape.modules.twitter.Tweet
# 5                            _type
# 6   snscrape.modules.twitter.Tweet
# 8                            _type
# 9   snscrape.modules.twitter.Tweet
# 12                           _type
# 13  snscrape.modules.twitter.Tweet
# 14                           _type
# 15  snscrape.modules.twitter.Tweet
# 17                           _type
#
#                                                   url  \
# 0   https://twitter.com/JahangirKTareen/status/147...
# 5                                                 url
# 6   https://twitter.com/AllenWest/status/147411078...
# 8                                                 url
# 9   https://twitter.com/alancampbellmp/status/1446...
# 12                                                url
# 13  https://twitter.com/RepMcGovern/status/1474117...
# 14                                                url
# 15  https://twitter.com/RepDwightEvans/status/1474...
# 17                                                url
#
#                          date  \
# 0   2021-12-15 09:47:19+00:00
# 5                        date
# 6   2021-12-23 20:12:54+00:00
# 8                        date
# 9   2021-10-08 11:36:44+00:00
# 12                       date
# 13  2021-12-23 20:39:31+00:00
# 14                       date
# 15  2021-12-23 21:04:56+00:00
# 17                       date
#
#                                               content  \
# 0   Regardless of the current status of my relatio...
# 5                                             content
# 6   I have signed the candidate pledge, as I am a ...
# 8                                             content
# 9   Deeply saddened to learn of the death of James...
# 12                                            content
# 13  Thank you @SpeakerPelosi for your unwavering l...
# 14                                            content
# 15  @ABCWorldNews @DavidMuir \n\nSource: https://t...
# 17                                            content
#
#                                       renderedContent                   id  \
# 0   Regardless of the current status of my relatio...  1471054251774332928
# 5                                     renderedContent                   id
# 6   I have signed the candidate pledge, as I am a ...  1474110787400744972
# 8                                     renderedContent                   id
# 9   Deeply saddened to learn of the death of James...  1446439412485742593
# 12                                    renderedContent                   id
# 13  Thank you @SpeakerPelosi for your unwavering l...  1474117486064906244
# 14                                    renderedContent                   id
# 15  @ABCWorldNews @DavidMuir \n\nSource: twitter.c...  1474123884127559693
# 17                                    renderedContent                   id
#
#                                                  user  replyCount  \
# 0   {'_type': 'snscrape.modules.twitter.User', 'us...        2108
# 5                                                user  replyCount
# 6   {'_type': 'snscrape.modules.twitter.User', 'us...           6
# 8                                                user  replyCount
# 9   {'_type': 'snscrape.modules.twitter.User', 'us...           3
# 12                                               user  replyCount
# 13  {'_type': 'snscrape.modules.twitter.User', 'us...           3
# 14                                               user  replyCount
# 15  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 17                                               user  replyCount
#
#     retweetCount  likeCount  ...  media  retweetedTweet  \
# 0           6038      31672  ...    NaN             NaN
# 5   retweetCount  likeCount  ...  media  retweetedTweet
# 6             27         72  ...    NaN             NaN
# 8   retweetCount  likeCount  ...  media  retweetedTweet
# 9              5         41  ...    NaN             NaN
# 12  retweetCount  likeCount  ...  media  retweetedTweet
# 13            13         70  ...    NaN             NaN
# 14  retweetCount  likeCount  ...  media  retweetedTweet
# 15             0          0  ...    NaN             NaN
# 17  retweetCount  likeCount  ...  media  retweetedTweet
#
#                                           quotedTweet     inReplyToTweetId  \
# 0                                                 NaN                  NaN
# 5                                         quotedTweet     inReplyToTweetId
# 6                                                 NaN                  NaN
# 8                                         quotedTweet     inReplyToTweetId
# 9                                                 NaN                  NaN
# 12                                        quotedTweet     inReplyToTweetId
# 13                                                NaN  1474117484068409362
# 14                                        quotedTweet     inReplyToTweetId
# 15  {'_type': 'snscrape.modules.twitter.Tweet', 'u...                  NaN
# 17                                        quotedTweet     inReplyToTweetId
#
#                                         inReplyToUser  \
# 0                                                 NaN
# 5                                       inReplyToUser
# 6                                                 NaN
# 8                                       inReplyToUser
# 9                                                 NaN
# 12                                      inReplyToUser
# 13  {'_type': 'snscrape.modules.twitter.User', 'us...
# 14                                      inReplyToUser
# 15                                                NaN
# 17                                      inReplyToUser
#
#                                        mentionedUsers  coordinates  place  \
# 0                                                 NaN          NaN    NaN
# 5                                      mentionedUsers  coordinates  place
# 6                                                 NaN          NaN    NaN
# 8                                      mentionedUsers  coordinates  place
# 9                                                 NaN          NaN    NaN
# 12                                     mentionedUsers  coordinates  place
# 13  [{'_type': 'snscrape.modules.twitter.User', 'u...          NaN    NaN
# 14                                     mentionedUsers  coordinates  place
# 15  [{'_type': 'snscrape.modules.twitter.User', 'u...          NaN    NaN
# 17                                     mentionedUsers  coordinates  place
#
#     hashtags  cashtags
# 0        NaN       NaN
# 5   hashtags  cashtags
# 6        NaN       NaN
# 8   hashtags  cashtags
# 9        NaN       NaN
# 12  hashtags  cashtags
# 13       NaN       NaN
# 14  hashtags  cashtags
# 15       NaN       NaN
# 17  hashtags  cashtags
#
# [10 rows x 28 columns]

# %%
import ast
List = test_df['user'][0]
List = ast.literal_eval(List)
List
# Out:
# {'_type': 'snscrape.modules.twitter.User',
#  'username': 'JahangirKTareen',
#  'id': 450504440,
#  'displayname': 'Jahangir Khan Tareen',
#  'description': 'Businessman, Farmer, Philanthropist and Politician Proud Member of #PTIFamily',
#  'rawDescription': 'Businessman, Farmer, Philanthropist and Politician Proud Member of #PTIFamily',
#  'descriptionUrls': None,
#  'verified': True,
#  'created': '2011-12-30T09:36:00+00:00',
#  'followersCount': 4086134,
#  'friendsCount': 139,
#  'statusesCount': 3309,
#  'favouritesCount': 33,
#  'listedCount': 1164,
#  'mediaCount': 388,
#  'location': 'Pakistan',
#  'protected': False,
#  'linkUrl': 'http://www.jahangirktareen.com',
#  'linkTcourl': 'https://t.co/GIipL5CqL1',
#  'profileImageUrl': 'https://pbs.twimg.com/profile_images/608234372416733184/d_KgCd7l_normal.jpg',
#  'profileBannerUrl': 'https://pbs.twimg.com/profile_banners/450504440/1569143573',
#  'label': None,
#  'url': 'https://twitter.com/JahangirKTareen'}
